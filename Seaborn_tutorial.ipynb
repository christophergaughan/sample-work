# %%
# Based on seaborn tutorial by Derek Banas- YouTube

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import Data

# %% [markdown]
# ### I'll import a dataset and try to work with that

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset("car_crashes")
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
crash_df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
crash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Distribution plot: provides distribution for one variable

# %%
sns.distplot(crash_df["not_distracted"], bins=25);
# Out:
# /Users/chrisgaughan/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Joint plot- used to compare to a distribution- it's a scatter plot

# %%
sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg")

# %%
sns.set_theme(style="dark")
sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="kde", palette="bone");

# %%
sns.set_theme(style="darkgrid")
sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="hex");

# %% [markdown]
# ## kde plot

# %%
sns.kdeplot(crash_df["alcohol"]);

# %% [markdown]
# ## Pair Plots

# %%
sns.pairplot(crash_df);

# %%
tips_df = sns.load_dataset("tips")
tips_df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.pairplot(tips_df);

# %%
sns.pairplot(tips_df, hue="sex", palette="magma");

# %% [markdown]
# ## Rug Plot

# %%
sns.rugplot(tips_df["tip"]);

# %% [markdown]
# ## Styling

# %%
sns.set_style("white")

plt.figure(figsize=(4,4))

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(4,4))

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(4,4))

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("dark")

plt.figure(figsize=(4,4))

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("ticks")

plt.figure(figsize=(4,4))

sns.set_context("paper", font_scale=2.0)

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("ticks")

plt.figure(figsize=(4,4))

sns.set_context("talk", font_scale=1.0)

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(4,4))

sns.set_context("poster", font_scale=1.0)

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg");

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(4,4))

sns.set_context("paper", font_scale=2.0)

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg")

sns.despine(left="True")

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(4,4))

sns.set_context("paper", font_scale=2.0)

sns.jointplot(x="speeding", y="alcohol", data=crash_df, kind="reg")

sns.despine(right="True", bottom="True")

# %% [markdown]
# ## Bar plots

# %%
sns.set_style("dark")

sns.set_context("paper", font_scale=1.5)

sns.barplot(x="sex", y="total_bill", data=tips_df, estimator=np.median);

# %% [markdown]
# ## Count Plot

# %%
sns.countplot(x = "sex", data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box Plot

# %%
sns.boxenplot(x = "day", y = "total_bill", hue="sex", data=tips_df);

# %%
sns.set_style("darkgrid")
sns.boxenplot(x = "day", y = "total_bill", hue="sex", data=tips_df);
plt.legend(loc=1)

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x = "day", y = "total_bill", hue="sex", data=tips_df);
plt.legend(loc=1)

# %%
sns.violinplot(x = "day", y = "total_bill", hue="sex", data=tips_df, split=True);
plt.legend(loc=1)

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x = "day", y = "total_bill", data=tips_df, jitter=True, hue = "sex", dodge=True);

# %% [markdown]
# ## Swarm Plot

# %%
sns.violinplot(x="day", y="total_bill", data=tips_df)
sns.swarmplot(x="day", y="total_bill", data=tips_df, palette="gist_heat")
sns.despine()

# %% [markdown]
# ## Palettes

# %%
plt.figure(figsize=(7,7))
sns.set_style("darkgrid")
sns.set_context=("talk")
sns.stripplot(x = "day", y = "total_bill", data=tips_df, hue="sex", palette="gist_heat");
plt.legend(loc=0)

# %% [markdown]
# ## Matrix Plots

# %% [markdown]
# ### Heatmaps

# %%
plt.figure(figsize=(8, 8))


crash_mx = crash_df.corr()

sns.heatmap(crash_mx, annot=True, cmap="viridis", linewidths=1, linecolor='black');

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# #### Making Pivot Tables

# %%
flights_pivot = flights.pivot_table(index="month", columns="year", values = "passengers")
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(7, 5))
sns.heatmap(flights_pivot, cmap="Blues", linewidths=0.5, linecolor="white");

# %% [markdown]
# ### Cluster Map

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# species  = iris.pop("species")
# sns.clustermap(iris)
sns.clustermap(flights_pivot, cmap = "Blues", standard_scale=1)

# %% [markdown]
# ## Pair Grid

# %%
isis = sns.load_dataset("iris")
# iris_g = sns.PairGrid(iris, hue="species", palette="gist_heat")
# iris_g.map_diag(plt.hist)
# iris_g.map_offdiag(plt.scatter)
# iris_g.map_upper(plt.scatter)
# iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue="species", palette="gist_heat",
                     x_vars=["sepal_length", "sepal_width"],
                     y_vars=["petal_length", "petal_width"])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# ## Facet Grid

# %%
tips_fg = sns.FacetGrid(tips_df, col="time", row="smoker")
tips_fg.map(plt.scatter, "total_bill", "tip")

# %%
tips_fg = sns.FacetGrid(tips_df, col="time", hue="smoker", palette="seismic", height=4, aspect=1,
                       col_order=["Dinner", "Lunch"])
tips_fg.map(plt.scatter, "total_bill", "tip", edgecolor="w")

# %%
kws = dict(s=50, linewidth=0.5, edgecolor="w")
tips_fg = sns.FacetGrid(tips_df, col="sex", hue="smoker", height=4, aspect=1.3,
                       hue_order=["Yes","No"],
                       hue_kws=dict(marker=["^", "v"]))
tips_fg.map(plt.scatter, "total_bill", "tip", **kws)

# %%
att_df = sns.load_dataset("attention")
att_fg = sns.FacetGrid(att_df, col="subject", col_wrap=5, height=1.5)
att_fg.map(plt.plot, "solutions", "score", marker = "^")

# %% [markdown]
# ## Regression Plots

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))
# sns.set_context("paper")
sns.lmplot(x = "total_bill", y="tip", hue="sex", data=tips_df, markers=["o", "^"],
          scatter_kws={"s":100, "linewidth": 0.5, "edgecolor":"w"})
